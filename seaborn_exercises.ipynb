# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pydataset import data

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Use the iris database to answer the following quesitons:
# ### 1. What does the distribution of petal lengths look like?

# %%
plt.title("Distribution of All Petal Lengths")
sns.histplot(x="petal_length", data=iris)
# Out:
# <AxesSubplot:title={'center':'Distribution of All Petal Lengths'}, xlabel='petal_length', ylabel='Count'>

# %%
plt.title("Distribution of Petal Lengths by species")
sns.histplot(x="petal_length", hue="species", data=iris)
# Out:
# <AxesSubplot:title={'center':'Distribution of Petal Lengths by species'}, xlabel='petal_length', ylabel='Count'>

# %%
# 2. Is there a correlation between petal length and petal width?
sns.relplot(x="petal_length", y="petal_width", data=iris)
plt.title("Relationship between petal length and petal width")
# Out:
# Text(0.5, 1.0, 'Relationship between petal length and petal width')

# %%
# 3. Would it be reasonable to predict species based on sepal width and sepal length?
# yes based on the charts below'

sns.relplot(x="petal_length", y="petal_width", data=iris, hue="species")
plt.title("Petal Length and Petal Width predict species well")
# Out:
# Text(0.5, 1.0, 'Petal Length and Petal Width predict species well')

# %%
# 4. Which features would be best used to predict species?
sns.pairplot(iris, hue="species")

# %% [markdown]
# # Using the lesson as an example, use seaborn's load_dataset function to load the anscombe data set. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?

# %%
anscombe = sns.load_dataset('anscombe')
anscombe.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
anscombe.groupby('dataset').agg(["min", "median", "mean", "std", "max"])
# Out:
#            x                                 y                             \
#          min median mean       std   max   min median      mean       std
# dataset
# I        4.0    9.0  9.0  3.316625  14.0  4.26   7.58  7.500909  2.031568
# II       4.0    9.0  9.0  3.316625  14.0  3.10   8.14  7.500909  2.031657
# III      4.0    9.0  9.0  3.316625  14.0  5.39   7.11  7.500000  2.030424
# IV       8.0    8.0  9.0  3.316625  19.0  5.25   7.04  7.500909  2.030579
#
#
#            max
# dataset
# I        10.84
# II        9.26
# III      12.74
# IV       12.50

# %%
# 1. Plot the x and y values from the anscombe data. Each dataset should be in a separate column.
sns.relplot(x="x", y="y", data=anscombe, col="dataset")
plt.suptitle("Plotting X and Y for each Anscombe set")
plt.tight_layout()

# %%
# 2. Load the InsectSprays dataset and read it's documentation. Create a boxplot that shows the effectiveness 
#of the different insect sprays.

sprays = data('InsectSprays', show_doc=True)
# Out:
# InsectSprays
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Effectiveness of Insect Sprays
#
# ### Description
#
# The counts of insects in agricultural experimental units treated with
# different insecticides.
#
# ### Usage
#
#     InsectSprays
#
# ### Format
#
# A data frame with 72 observations on 2 variables.
#
# [,1]
#
# count
#
# numeric
#
# Insect count
#
# [,2]
#
# spray
#
# factor
#
# The type of spray
#
# ### Source
#
# Beall, G., (1942) The Transformation of data from entomological field
# experiments, _Biometrika_, **29**, 243–262.
#
# ### References
#
# McNeil, D. (1977) _Interactive Data Analysis_. New York: Wiley.
#
# ### Examples
#
#     require(stats); require(graphics)
#     boxplot(count ~ spray, data = InsectSprays,
#             xlab = "Type of spray", ylab = "Insect count",
#             main = "InsectSprays data", varwidth = TRUE, col = "lightgray")
#     fm1 <- aov(count ~ spray, data = InsectSprays)
#     summary(fm1)
#     opar <- par(mfrow = c(2, 2), oma = c(0, 0, 1.1, 0))
#     plot(fm1)
#     fm2 <- aov(sqrt(count) ~ spray, data = InsectSprays)
#     summary(fm2)
#     plot(fm2)
#     par(opar)

# %%
sprays = data("InsectSprays")
sprays.head()
# Out:
#    count spray
# 1     10     A
# 2      7     A
# 3     20     A
# 4     14     A
# 5     14     A

# %%
# 2. Create a boxplot that shows the effectiveness of the different insect sprays.

plt.title("Boxplot Showing Surviving Bug Counts After Being Sprayed")
sns.boxplot(data=sprays, x = 'spray', y = 'count')
# Out:
# <AxesSubplot:title={'center':'Boxplot Showing Surviving Bug Counts After Being Sprayed'}, xlabel='spray', ylabel='count'>

# %% [markdown]
# # 3. Load the swiss dataset and read it's documentation. Create visualizations to answer the following questions:

# %%
swiss = data("swiss")
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
sns.histplot(swiss.Catholic)
plt.title("Distribution of % Catholic count")
plt.show()

# %%
# 3. Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. 
# (Choose a cutoff point for what constitutes catholic)
swiss["is_catholic"] = swiss.Catholic > 50

# %%
# 3. Does whether or not a province is Catholic influence fertility?
sns.boxplot(data=swiss, x="is_catholic", y="Fertility")
plt.title("Fertility Is Higher in Majority Catholic Provinces")
# Out:
# Text(0.5, 1.0, 'Fertility Is Higher in Majority Catholic Provinces')

# %%
# 3. What measure correlates most strongly with fertility?
