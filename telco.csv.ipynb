# %%
import pandas as pd

# %%
df = pd.read_csv('~/Downloads/telco.csv')
print (df)
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7038  9987-LUTYD  Female                  0      No         No              1
# 7039  9992-RRAMN    Male                  0     Yes         No              2
# 7040  9992-UJOEL    Male                  0      No         No              1
# 7041  9993-LHIEB    Male                  0     Yes        Yes              1
# 7042  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
df.head()
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  0002-ORFBO  Female                  0     Yes        Yes              1
# 1  0003-MKNFE    Male                  0      No         No              2
# 2  0004-TLHLJ    Male                  0      No         No              1
# 3  0011-IGKFF    Male                  1     Yes         No              1
# 4  0013-EXCHZ  Female                  1     Yes         No              1
#
#    internet_service  contract_type      payment_type monthly_charges  ...  \
# 0                 1              1      Mailed check          $65.60  ...
# 1                 1              0      Mailed check          $59.90  ...
# 2                 2              0  Electronic check          $73.90  ...
# 3                 2              0  Electronic check          $98.00  ...
# 4                 2              0      Mailed check          $83.90  ...
#
# ...

# %%
df.tail()
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 7038  9987-LUTYD  Female                  0      No         No              1
# 7039  9992-RRAMN    Male                  0     Yes         No              2
# 7040  9992-UJOEL    Male                  0      No         No              1
# 7041  9993-LHIEB    Male                  0     Yes        Yes              1
# 7042  9995-HOTOH    Male                  0     Yes        Yes              0
#
#       internet_service  contract_type      payment_type monthly_charges  ...  \
# 7038                 1              1      Mailed check          $55.15  ...
# 7039                 2              0  Electronic check          $85.10  ...
# 7040                 1              0      Mailed check          $50.30  ...
# 7041                 1              2      Mailed check          $67.85  ...
# 7042                 1              2  Electronic check          $59.00  ...
#
# ...

# %%
df.describe()
# Out:
#        is_senior_citizen  phone_service  internet_service  contract_type  \
# count        7043.000000    7043.000000       7043.000000    7043.000000
# mean            0.162147       1.325004          1.222916       0.690473
# std             0.368612       0.642730          0.778877       0.833755
# min             0.000000       0.000000          0.000000       0.000000
# 25%             0.000000       1.000000          1.000000       0.000000
# 50%             0.000000       1.000000          1.000000       0.000000
# 75%             0.000000       2.000000          2.000000       1.000000
# max             1.000000       2.000000          2.000000       2.000000
#
#        monthly_tenure  partner_dependents
# count     7043.000000         7043.000000
# mean        32.368309            1.082209
# std         24.597021            1.226274
# min          0.000000            0.000000
# 25%          9.000000            0.000000
# 50%         29.000000            1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               7043 non-null   object
#  1   gender                    7043 non-null   object
#  2   is_senior_citizen         7043 non-null   int64
#  3   partner                   7043 non-null   object
#  4   dependents                7043 non-null   object
#  5   phone_service             7043 non-null   int64
#  6   internet_service          7043 non-null   int64
#  7   contract_type             7043 non-null   int64
#  8   payment_type              7043 non-null   object
#  9   monthly_charges           7043 non-null   object
#  10  total_charges             7032 non-null   object
#  11  churn                     7043 non-null   object
#  12  monthly_tenure            7043 non-null   int64
#  13  is_female                 7043 non-null   bool
# ...

# %%
df.shape
# Out:
# (7043, 26)

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'is_senior_citizen', 'partner', 'dependents',
#        'phone_service', 'internet_service', 'contract_type', 'payment_type',
#        'monthly_charges', 'total_charges', 'churn', 'monthly_tenure',
#        'is_female', 'has_churned', 'has_phone', 'has_internet',
#        'has_phone_and_internet', 'partner_dependents', 'start_date',
#        'average_monthly_charges', 'validate_monthly_charges',
#        'contract_type_desc', 'internet_type_desc', 'internet_type_desc.1',
#        'service_type'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7043, step=1)

# %%
df.dtypes
# Out:
# customer_id                 object
# gender                      object
# is_senior_citizen            int64
# partner                     object
# dependents                  object
# phone_service                int64
# internet_service             int64
# contract_type                int64
# payment_type                object
# monthly_charges             object
# total_charges               object
# churn                       object
# monthly_tenure               int64
# is_female                     bool
# has_churned                   bool
# has_phone                     bool
# has_internet                  bool
# has_phone_and_internet        bool
# partner_dependents           int64
# start_date                  object
# average_monthly_charges     object
# validate_monthly_charges      bool
# contract_type_desc          object
# internet_type_desc          object
# internet_type_desc.1        object
# service_type                object
# dtype: object

# %%
df.sort_values(by='churn')
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 4375  6169-PPETC    Male                  0     Yes        Yes              1
# 4374  6169-PGNCD  Female                  0      No         No              1
# 4373  6168-YBYNP    Male                  0      No         No              2
# 4371  6166-YIPFO    Male                  0     Yes         No              0
# ...          ...     ...                ...     ...        ...            ...
# 4815  6772-KSATR    Male                  0      No         No              2
# 4818  6776-TLWOI    Male                  0      No         No              1
# 4819  6777-TGHTM  Female                  0      No         No              2
# 4866  6857-VWJDT  Female                  0      No         No              2
# 1510  2219-MVUSO    Male                  0      No         No              1
#
# ...
